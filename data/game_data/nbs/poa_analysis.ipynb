# %%
import matplotlib.pyplot as plt
import nashpy as nash
import numpy as np
import pandas as pd
import pathlib

import ambulance_game as abg
from main import (
    get_index_of_values,
    get_matrices,
    get_poa_values_for_given_strategies,
    run_replicator_dynamics_with_penalty,
    plot_asymmetric_replicator_dynamics_with_penalty,
    run_replicator_dynamics_with_dual_parameters,
    get_poa_values_for_given_strategies_dual_parameters,
    plot_asymmetric_replicator_dynamics_with_dual_parameters
)

# %%
df = pd.read_csv(pathlib.Path("../data/_parameters/main.csv"))

# %%
problem_parameters = {
        "alpha": 0.9,
        "buffer_capacity_1": 5,
        "buffer_capacity_2": 4,
        "lambda_1_1": 4.5,
        "lambda_1_2": 6,
        "lambda_2": 10.7,
        "mu_1": 2,
        "mu_2": 3,
        "num_of_servers_1": 3,
        "num_of_servers_2": 2,
        "system_capacity_1": 6,
        "system_capacity_2": 7,
        "target": 2,
    }

# %% [markdown]
# # Reading and scaling matrices

# %%
index = get_index_of_values(problem_parameters, atol=1e-1, data=df)
dirname = df.iloc[index[0]]["hash_value"]
R, A, B = get_matrices(dirname)
A += 1
B += 1

# %% [markdown]
# # Asymmetric replicator dynamics behaviour - blocking time

# %%
plot_asymmetric_replicator_dynamics_with_penalty(
    R=R, 
    A=A, 
    B=B, 
    problem_parameters=problem_parameters,
    performance_measure_function=abg.markov.get_mean_blocking_time_using_markov_state_probabilities,
    timepoints=np.linspace(1, 100000, 100), 
    penalty=None, 
    poa_plot_min=0, 
    poa_plot_max=10,
)

# %% [markdown]
# ## Flooding the system (increasing $\lambda_2$)

# %%
index = get_index_of_values(problem_parameters, atol=1e-1, data=df)
dirname = df.iloc[index[0]]["hash_value"]
R1, A1, B1 = get_matrices(dirname)
A1 += 1
B1 += 1

problem_parameters_2 = problem_parameters.copy()
problem_parameters_2["lambda_2"] = 24
index = get_index_of_values(problem_parameters_2, atol=1e-1, data=df)
dirname = df.iloc[index[0]]["hash_value"]
R2, A2, B2 = get_matrices(dirname)
A2 += 1
B2 += 1

# %%
plot_asymmetric_replicator_dynamics_with_dual_parameters(
    R1=R1,
    A1=A1,
    B1=B1,
    R2=R2,
    A2=A2,
    B2=B2,
    timepoints=np.linspace(1, 100000, 100),
    problem_parameters_1=problem_parameters,
    problem_parameters_2=problem_parameters_2,
    x_init=None,
    y_init=None,
    poa_plot_max=None,
    poa_plot_min=None,
    performance_measure_function=abg.markov.get_mean_blocking_time_using_markov_state_probabilities,
)

# %% [markdown]
# ## Adding resources (increasing $N_1$ and $N_2$)

# %%
index = get_index_of_values(problem_parameters, atol=1e-1, data=df)
dirname = df.iloc[index[0]]["hash_value"]
R1, A1, B1 = get_matrices(dirname)
A1 += 1
B1 += 1

problem_parameters_2 = problem_parameters.copy()
problem_parameters_2["system_capacity_1"] = 7
problem_parameters_2["system_capacity_2"] = 8
index = get_index_of_values(problem_parameters_2, atol=1e-1, data=df)
dirname = df.iloc[index[0]]["hash_value"]
R2, A2, B2 = get_matrices(dirname)
A2 += 1
B2 += 1

# %%
plot_asymmetric_replicator_dynamics_with_dual_parameters(
    R1=R1,
    A1=A1,
    B1=B1,
    R2=R2,
    A2=A2,
    B2=B2,
    timepoints=np.linspace(1, 1000000, 100),
    divide=6,
    problem_parameters_1=problem_parameters,
    problem_parameters_2=problem_parameters_2,
    poa_plot_max=None,
    poa_plot_min=None,
    performance_measure_function=abg.markov.get_mean_blocking_time_using_markov_state_probabilities,
)

# %% [markdown]
# ## Adding resources (increasing $M_1$ and $M_2$)

# %%
index = get_index_of_values(problem_parameters, atol=1e-1, data=df)
dirname = df.iloc[index[0]]["hash_value"]
R1, A1, B1 = get_matrices(dirname)

problem_parameters_2 = problem_parameters.copy()
problem_parameters_2["buffer_capacity_1"] = 9
problem_parameters_2["buffer_capacity_2"] = 5
index = get_index_of_values(problem_parameters_2, atol=1e-1, data=df)
dirname = df.iloc[index[0]]["hash_value"]
R2, A2, B2 = get_matrices(dirname)

A1 += 1
A2 += 1
B1 += 1
B2 += 1

# %%
plot_asymmetric_replicator_dynamics_with_dual_parameters(
    R1=R1,
    A1=A1,
    B1=B1,
    R2=R2,
    A2=A2,
    B2=B2,
    divide=3,
    timepoints=np.linspace(1, 100000, 100),
    problem_parameters_1=problem_parameters,
    problem_parameters_2=problem_parameters_2,
    poa_plot_max=None,
    poa_plot_min=None,
    performance_measure_function=abg.markov.get_mean_blocking_time_using_markov_state_probabilities,
)

# %% [markdown]
# ## Increasing number of servers $C$

# %%
index = get_index_of_values(problem_parameters, atol=1e-1, data=df)
dirname = df.iloc[index[0]]["hash_value"]
R1, A1, B1 = get_matrices(dirname)

# %%
problem_parameters_2 = problem_parameters.copy()
problem_parameters_2["num_of_servers_1"] = 4
problem_parameters_2["num_of_servers_2"] = 3
index = get_index_of_values(problem_parameters_2, atol=1e-1, data=df)
dirname = df.iloc[index[0]]["hash_value"]
R2, A2, B2 = get_matrices(dirname)

# %%
A1 += 1
A2 += 1
B1 += 1
B2 += 1

# %%
plot_asymmetric_replicator_dynamics_with_dual_parameters(
    R1=R1,
    A1=A1,
    B1=B1,
    R2=R2,
    A2=A2,
    B2=B2,
    divide=3,
    timepoints=np.linspace(1, 100000, 100),
    problem_parameters_1=problem_parameters,
    problem_parameters_2=problem_parameters_2,
    poa_plot_max=None,
    poa_plot_min=None,
    performance_measure_function=abg.markov.get_mean_blocking_time_using_markov_state_probabilities,
)

# %% [markdown]
# ## Penalise strategies

# %% [markdown]
# $$
#     A =
#     \begin{pmatrix}
#         x & x & x & x \\
#         x & x & x & x \\
#         x & x & x & x \\
#     \end{pmatrix}, \;
#     B =
#     \begin{pmatrix}
#         y & y & y & y \\
#         y & y & y & y \\
#         y & y & y & y \\
#     \end{pmatrix}
# $$
#
# $$
#     \tilde{A} =
#     \begin{pmatrix}
#         x & x & x & x \\
#         \rho x & \rho x & \rho x & \rho x \\
#         x & x & x & x \\
#     \end{pmatrix}, \;
#     \tilde{B} =
#     \begin{pmatrix}
#         y & \rho y & y & y \\
#         y & \rho y & y & y \\
#         y & \rho y & y & y \\
#     \end{pmatrix}
# $$

# %%
index = get_index_of_values(problem_parameters, atol=1e-1, data=df)
dirname = df.iloc[index[0]]["hash_value"]
R, A, B = get_matrices(dirname)
A += 1
B += 1

# %%
plot_asymmetric_replicator_dynamics_with_penalty(
    R=R,
    A=A,
    B=B,
    problem_parameters=problem_parameters,
    performance_measure_function=abg.markov.get_mean_blocking_time_using_markov_state_probabilities,
    timepoints=np.linspace(1, 100000, 100), 
    penalty=0.9997,
    poa_plot_min=0, 
    poa_plot_max=5,
)

# %% [markdown]
# # Increasing artificial values $N_1$, $N_2$, $M_1$ and $M_2$

# %%
problem_parameters = {
        "alpha": 0.9,
        "buffer_capacity_1": 10, # 5
        "buffer_capacity_2": 8,  # 4
        "lambda_1_1": 4.5,
        "lambda_1_2": 6,
        "lambda_2": 10.7,
        "mu_1": 2,
        "mu_2": 3,
        "num_of_servers_1": 3,
        "num_of_servers_2": 2,
        "system_capacity_1": 12, # 6
        "system_capacity_2": 14, # 7
        "target": 2,
    }

# %%
index = get_index_of_values(problem_parameters, atol=1e-1, data=df)
dirname = df.iloc[index[0]]["hash_value"]
R, A, B = get_matrices(dirname)
A += 1
B += 1

# %%
plot_asymmetric_replicator_dynamics_with_penalty(
    R=R,
    A=A,
    B=B,
    problem_parameters=problem_parameters,
    performance_measure_function=abg.markov.get_mean_blocking_time_using_markov_state_probabilities,
    timepoints=np.linspace(1, 10000, 100), 
)

# %% [markdown]
# ## Penalise strategies

# %%
index = get_index_of_values(problem_parameters, atol=1e-1, data=df)
dirname = df.iloc[index[0]]["hash_value"]
R, A, B = get_matrices(dirname)
A += 1
B += 1

# %%
plot_asymmetric_replicator_dynamics_with_penalty(
    R=R,
    A=A,
    B=B,
    problem_parameters=problem_parameters,
    performance_measure_function=abg.markov.get_mean_blocking_time_using_markov_state_probabilities,
    timepoints=np.linspace(1, 10000, 100), 
    penalty=0.995,
)

# %% [markdown]
# # Appendix

# %%
problem_parameters = {
    "alpha": 0.9,
    "buffer_capacity_1": 10, # 5
    "buffer_capacity_2": 8,  # 4
    "lambda_1_1": 4.5,
    "lambda_1_2": 6,
    "lambda_2": 10.7,
    "mu_1": 2,
    "mu_2": 3,
    "num_of_servers_1": 3,
    "num_of_servers_2": 2,
    "system_capacity_1": 12, # 6
    "system_capacity_2": 14, # 7
    "target": 2,
}

index = get_index_of_values(problem_parameters, atol=1e-1, data=df)
dirname = df.iloc[index[0]]["hash_value"]
R, A, B = get_matrices(dirname)
A += 1
B += 1

xs, ys = nash.Game(A, B).asymmetric_replicator_dynamics(timepoints=np.linspace(1, 10000, 100))

plt.figure(figsize=(15, 10))
plt.subplot(2, 2, 1)
plt.plot(xs)
plt.xlabel("Timepoints")
plt.ylabel("Probability")
plt.title("Row player")
plt.legend([f"$s_{{{i + 1}}}$" for i in range(len(xs[0]))])

plt.subplot(2, 2, 2)
plt.plot(ys)
plt.xlabel("Timepoints")
plt.ylabel("Probability")
plt.title("Column player")
plt.legend([f"$s_{{{i + 1}}}$" for i in range(len(ys[0]))])

# %% [markdown]
# ## 1. Asymmetric replicator dynamics behaviour - waiting time

# %%
problem_parameters = {
        "alpha": 0.9,
        "buffer_capacity_1": 5,
        "buffer_capacity_2": 4,
        "lambda_1_1": 4.5,
        "lambda_1_2": 6,
        "lambda_2": 10.7,
        "mu_1": 2,
        "mu_2": 3,
        "num_of_servers_1": 3,
        "num_of_servers_2": 2,
        "system_capacity_1": 6,
        "system_capacity_2": 7,
        "target": 2,
    }

# %%
index = get_index_of_values(problem_parameters, atol=1e-1, data=df)
dirname = df.iloc[index[0]]["hash_value"]
R, A, B = get_matrices(dirname)
A *= 100
B *= 100

# %%
plot_asymmetric_replicator_dynamics_with_penalty(
    R=R, 
    A=A, 
    B=B, 
    problem_parameters=problem_parameters,
    performance_measure_function=abg.markov.get_mean_waiting_time_using_markov_state_probabilities,
    timepoints=np.linspace(1, 1000, 100), 
    penalty=None, 
    poa_plot_min=0, 
    poa_plot_max=10,
)

# %% [markdown]
# ### FLooding the system

# %%
index = get_index_of_values(problem_parameters, atol=1e-1, data=df)
dirname = df.iloc[index[0]]["hash_value"]
R1, A1, B1 = get_matrices(dirname)
A1 *= 100
B1 *= 100

problem_parameters_2 = problem_parameters.copy()
problem_parameters_2["lambda_2"] = 24
index = get_index_of_values(problem_parameters_2, atol=1e-1, data=df)
dirname = df.iloc[index[0]]["hash_value"]
R2, A2, B2 = get_matrices(dirname)
A2 *= 100
B2 *= 100

# %%
plot_asymmetric_replicator_dynamics_with_dual_parameters(
    R1=R1,
    A1=A1,
    B1=B1,
    R2=R2,
    A2=A2,
    B2=B2,
    timepoints=np.linspace(1, 10000, 100),
    problem_parameters_1=problem_parameters,
    problem_parameters_2=problem_parameters_2,
    poa_plot_max=None,
    poa_plot_min=None,
    performance_measure_function=abg.markov.get_mean_waiting_time_using_markov_state_probabilities,
)

# %% [markdown]
# ### Adding resources (increasing $N_1$ and $N_2$)

# %%
index = get_index_of_values(problem_parameters, atol=1e-1, data=df)
dirname = df.iloc[index[0]]["hash_value"]
R1, A1, B1 = get_matrices(dirname)

problem_parameters_2 = problem_parameters.copy()
problem_parameters_2["system_capacity_1"] = 7
problem_parameters_2["system_capacity_2"] = 8
index = get_index_of_values(problem_parameters_2, atol=1e-1, data=df)
dirname = df.iloc[index[0]]["hash_value"]
R2, A2, B2 = get_matrices(dirname)

# %%
plot_asymmetric_replicator_dynamics_with_dual_parameters(
    R1=R1,
    A1=A1,
    B1=B1,
    R2=R2,
    A2=A2,
    B2=B2,
    divide=3,
    timepoints=np.linspace(1, 100000, 100),
    problem_parameters_1=problem_parameters,
    problem_parameters_2=problem_parameters_2,
    poa_plot_max=None,
    poa_plot_min=None,
    performance_measure_function=abg.markov.get_mean_blocking_time_using_markov_state_probabilities,
)

# %% [markdown]
# ## Penalise strategy

# %%
plot_asymmetric_replicator_dynamics_with_penalty(
    R=R, 
    A=A, 
    B=B, 
    problem_parameters=problem_parameters,
    performance_measure_function=abg.markov.get_mean_waiting_time_using_markov_state_probabilities,
    timepoints=np.linspace(1, 1000, 100), 
    penalty=100, 
    poa_plot_min=0, 
    poa_plot_max=5,
)

# %% [markdown]
# ## 2. General behaviour of increased capacity model

# %%
problem_parameters = {
        "alpha": 0.9,
        "buffer_capacity_1": 5,
        "buffer_capacity_2": 4,
        "lambda_1_1": 4.5,
        "lambda_1_2": 6,
        "lambda_2": 10.7,
        "mu_1": 2,
        "mu_2": 3,
        "num_of_servers_1": 3,
        "num_of_servers_2": 2,
        "system_capacity_1": 6,
        "system_capacity_2": 7,
        "target": 2,
    }

# %%
index = get_index_of_values(problem_parameters, atol=1e-1, data=df)
dirname = df.iloc[index[0]]["hash_value"]
R1, A1, B1 = get_matrices(dirname)

problem_parameters_2 = problem_parameters.copy()
problem_parameters_2["system_capacity_1"] = 7
problem_parameters_2["system_capacity_2"] = 8
index = get_index_of_values(problem_parameters_2, atol=1e-1, data=df)
dirname = df.iloc[index[0]]["hash_value"]
R2, A2, B2 = get_matrices(dirname)

# %%
game = nash.Game(A2, B2)
xs, ys = game.asymmetric_replicator_dynamics(
    timepoints=np.linspace(0, 500000, 100), 
    x0=np.array([.01, .01, .01, .01, .94, .01, .01]),
    y0=np.array([.01, .01, .01, .01, .01, .93, .01, .01]),
)
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(xs)
plt.legend([f"$s_{i + 1}$" for i in range(7)])
plt.subplot(1, 2, 2)
plt.plot(ys)
plt.legend([f"$s_{i + 1}$" for i in range(8)])

# %% [markdown]
# ## 3. Another exaple (addition instead of scaling) - waiting time

# %%
problem_parameters = {
        "alpha": 0.9,
        "buffer_capacity_1": 7,
        "buffer_capacity_2": 4,
        "lambda_1_1": 1.0,
        "lambda_1_2": 4.9,
        "lambda_2": 21.3,
        "mu_1": 4.2,
        "mu_2": 6.6,
        "num_of_servers_1": 1,
        "num_of_servers_2": 3,
        "system_capacity_1": 2,
        "system_capacity_2": 6,
        "target": 1,
    }

# %%
index = get_index_of_values(problem_parameters, atol=1e-1, data=df)
dirname = df.iloc[index[0]]["hash_value"]
R, A, B = get_matrices(dirname)
A += 1
B += 1

# %%
plot_asymmetric_replicator_dynamics_with_penalty(
    R=R, 
    A=A, 
    B=B, 
    problem_parameters=problem_parameters,
    performance_measure_function=abg.markov.get_mean_waiting_time_using_markov_state_probabilities,
    timepoints=np.linspace(0, 200000, 100), 
    penalty=None, 
    poa_plot_min=None, 
    poa_plot_max=None,
)

# %%
plot_asymmetric_replicator_dynamics_with_penalty(
    R=R, 
    A=A, 
    B=B, 
    problem_parameters=problem_parameters,
    performance_measure_function=abg.markov.get_mean_waiting_time_using_markov_state_probabilities,
    timepoints=np.linspace(0, 200000, 100), 
    penalty=0.9996, 
    poa_plot_min=None, 
    poa_plot_max=None,
)

# %% [markdown]
# ## 4. Issue with asymmetric replicator dynamics

# %%
problem_parameters = {
        "alpha": 0.9,
        "buffer_capacity_1": 7,
        "buffer_capacity_2": 4,
        "lambda_1_1": 1.0,
        "lambda_1_2": 4.9,
        "lambda_2": 21.3,
        "mu_1": 4.2,
        "mu_2": 6.6,
        "num_of_servers_1": 1,
        "num_of_servers_2": 3,
        "system_capacity_1": 2,
        "system_capacity_2": 6,
        "target": 1,
    }
index = get_index_of_values(problem_parameters, atol=1e-1, data=df)
dirname = df.iloc[index[0]]["hash_value"]
R, A, B = get_matrices(dirname)

# %%
A
# Out:
# array([[-0.00050514, -0.00050514, -0.00050514, -0.00050514, -0.00050514,
#         -0.00050514],
#        [-0.0007705 , -0.00071238, -0.00056314, -0.00053245, -0.00047844,
#         -0.00028032]])

# %%
B
# Out:
# array([[-0.00236188, -0.00235826, -0.00234432, -0.00228569, -0.00221157,
#         -0.00214314],
#        [-0.00236188, -0.0023583 , -0.00234467, -0.00228815, -0.00221752,
#         -0.00215414]])

# %%
xs, ys = nash.Game(A, B).asymmetric_replicator_dynamics(timepoints=np.linspace(0, 100000, 100))
plt.plot(xs)
# Out:
# [<matplotlib.lines.Line2D at 0x21c47b5ec40>,
#  <matplotlib.lines.Line2D at 0x21c46e9f760>]

# %%
plt.plot(ys)
# Out:
# [<matplotlib.lines.Line2D at 0x21c46184610>,
#  <matplotlib.lines.Line2D at 0x21c461846d0>,
#  <matplotlib.lines.Line2D at 0x21c46184790>,
#  <matplotlib.lines.Line2D at 0x21c46184850>,
#  <matplotlib.lines.Line2D at 0x21c46184910>,
#  <matplotlib.lines.Line2D at 0x21c461849d0>]

# %%
A += 1
B += 1

# %%
xs, ys = nash.Game(A, B).asymmetric_replicator_dynamics(timepoints=np.linspace(0, 100000, 100))
plt.plot(xs)
# Out:
# [<matplotlib.lines.Line2D at 0x21c462d4eb0>,
#  <matplotlib.lines.Line2D at 0x21c462d4f70>]

# %%
plt.plot(ys)
# Out:
# [<matplotlib.lines.Line2D at 0x21c46157160>,
#  <matplotlib.lines.Line2D at 0x21c46157220>,
#  <matplotlib.lines.Line2D at 0x21c461572e0>,
#  <matplotlib.lines.Line2D at 0x21c461573a0>,
#  <matplotlib.lines.Line2D at 0x21c46157460>,
#  <matplotlib.lines.Line2D at 0x21c46157520>]
