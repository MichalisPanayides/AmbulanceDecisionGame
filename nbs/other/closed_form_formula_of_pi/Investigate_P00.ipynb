# %%
import ambulance_game as abg
import sympy as sym
from state_probabilities_examples.main import (
    get_symbolic_state_probabilities_1222,
    get_symbolic_state_probabilities_1121,
    get_symbolic_state_probabilities_1122,
    get_symbolic_state_probabilities_1123,
    get_symbolic_state_probabilities_1341,
    get_symbolic_state_probabilities_1131,
    get_symbolic_state_probabilities_1132,
    get_symbolic_state_probabilities_1141,
    get_symbolic_state_probabilities_1142,
    get_symbolic_state_probabilities_1151,
    get_symbolic_state_probabilities_1161,
    get_symbolic_state_probabilities_1171,
    get_symbolic_state_probabilities_1181,
)
p00, p01, p11, p21, p31, p02, p12, p22, p32, p03, p13, p23, p04, p14, p24, p05, p15, p25, p06, p16, p26, p07, p17, p27, p08, p18, p28 = sym.symbols('p00, p01, p11, p21, p31, p02, p12, p22, p32, p03, p13, p23, p04, p14, p24, p05, p15, p25, p06, p16, p26, p07, p17, p27, p08, p18, p28')
sym_Lambda = sym.symbols("Lambda")
sym_lambda_o = sym.symbols("lambda^o")
sym_lambda_a = sym.symbols("lambda^A")
sym_mu = sym.symbols("mu")

# %%
sym.init_printing(use_latex='mathjax')

# %%
probs_1222, _ = get_symbolic_state_probabilities_1222()
probs_1121, _, _, _ = get_symbolic_state_probabilities_1121()
probs_1122, _, _, _ = get_symbolic_state_probabilities_1122()
probs_1123, _, _, _ = get_symbolic_state_probabilities_1123()
probs_1341, _, _, _ = get_symbolic_state_probabilities_1341()
probs_1131, _, _, _ = get_symbolic_state_probabilities_1131()
probs_1132, _, _, _ = get_symbolic_state_probabilities_1132()
probs_1141, _, _, _ = get_symbolic_state_probabilities_1141()
probs_1142, _, _, _ = get_symbolic_state_probabilities_1142()
probs_1151, _, _, _ = get_symbolic_state_probabilities_1151()
probs_1161, _, _, _ = get_symbolic_state_probabilities_1161()

# %%
probs_1141, _, _, _ = get_symbolic_state_probabilities_1141()
probs_1142, _, _, _ = get_symbolic_state_probabilities_1142()

# %%
probs_1121, _, _, _ = get_symbolic_state_probabilities_1121()
probs_1131, _, _, _ = get_symbolic_state_probabilities_1131()

# %%
probs_1171, _, _, _ = get_symbolic_state_probabilities_1171()

# %%
probs_1181, _, _, _ = get_symbolic_state_probabilities_1181()

# %%
abg.markov.visualise_ambulance_markov_chain(num_of_servers=1, threshold=2, system_capacity=2, parking_capacity=2)

# %%
sym.fraction(probs_1222[0])[0]
# Out:
#  4
# μ

# %%
abg.markov.visualise_ambulance_markov_chain(num_of_servers=1, threshold=1, system_capacity=2, parking_capacity=1)

# %%
sym.fraction(probs_1121[0])[0]
# Out:
#  3
# μ ⋅(λ__A + μ)

# %%
abg.markov.visualise_ambulance_markov_chain(num_of_servers=1, threshold=3, system_capacity=4, parking_capacity=1)

# %%
sym.fraction(sym.factor(probs_1341[0]))[0]
# Out:
#  5
# μ ⋅(λ__A + μ)

# %% [markdown]
# # Change in $P_{0,0}$ when adding rows

# %%
abg.markov.visualise_ambulance_markov_chain(num_of_servers=1, threshold=1, system_capacity=2, parking_capacity=1)

# %%
sym.fraction(probs_1121[0])[0]
# Out:
#  3
# μ ⋅(λ__A + μ)

# %%
abg.markov.visualise_ambulance_markov_chain(num_of_servers=1, threshold=1, system_capacity=2, parking_capacity=2)

# %%
sym.fraction(sym.factor(probs_1122[0]))[0]
# Out:
#  4           2
# μ ⋅(λ__A + μ)

# %%
abg.markov.visualise_ambulance_markov_chain(num_of_servers=1, threshold=1, system_capacity=2, parking_capacity=3)

# %%
sym.fraction(sym.factor(probs_1123[p00]))[0]
# Out:
#  5           3
# μ ⋅(λ__A + μ)

# %%
abg.markov.visualise_ambulance_markov_chain(num_of_servers=1, threshold=1, system_capacity=3, parking_capacity=1)

# %%
sym.fraction(sym.factor(probs_1131[0]))[0]
# Out:
#  4 ⎛    2                           2⎞
# μ ⋅⎝λ__A  + λ__A⋅λ__o + 2⋅λ__A⋅μ + μ ⎠

# %%
abg.markov.visualise_ambulance_markov_chain(num_of_servers=1, threshold=1, system_capacity=3, parking_capacity=2)

# %%
sym.fraction(sym.factor(probs_1132[p00]))[0]
# Out:
#                                       2
#  5 ⎛    2                           2⎞
# μ ⋅⎝λ__A  + λ__A⋅λ__o + 2⋅λ__A⋅μ + μ ⎠

# %%
abg.markov.visualise_ambulance_markov_chain(num_of_servers=1, threshold=1, system_capacity=4, parking_capacity=1)

# %%
sym.fraction(sym.factor(probs_1141[p00]))[0]
# Out:
#  5 ⎛    3         2              2              2                           2
# μ ⋅⎝λ__A  + 2⋅λ__A ⋅λ__o + 3⋅λ__A ⋅μ + λ__A⋅λ__o  + 2⋅λ__A⋅λ__o⋅μ + 3⋅λ__A⋅μ
#
#    3⎞
# + μ ⎠

# %%
abg.markov.visualise_ambulance_markov_chain(num_of_servers=1, threshold=1, system_capacity=4, parking_capacity=2)

# %%
sym.fraction(sym.factor(probs_1142[p00]))[0]
# Out:
#
#  6 ⎛    3         2              2              2                           2
# μ ⋅⎝λ__A  + 2⋅λ__A ⋅λ__o + 3⋅λ__A ⋅μ + λ__A⋅λ__o  + 2⋅λ__A⋅λ__o⋅μ + 3⋅λ__A⋅μ
#
#      2
#    3⎞
# + μ ⎠

# %% [markdown]
# # Change in $P_{0,0}$ when adding columns

# %%
abg.markov.visualise_ambulance_markov_chain(num_of_servers=1, threshold=1, system_capacity=2, parking_capacity=1)

# %%
sym.fraction(sym.factor(probs_1121[0]))[0]
# Out:
#  3
# μ ⋅(λ__A + μ)

# %%
abg.markov.visualise_ambulance_markov_chain(num_of_servers=1, threshold=1, system_capacity=3, parking_capacity=1)

# %%
sym.fraction(sym.factor(probs_1131[0]))[0]
# Out:
#  4 ⎛    2                           2⎞
# μ ⋅⎝λ__A  + λ__A⋅λ__o + 2⋅λ__A⋅μ + μ ⎠

# %%
sym_mu ** 4 * ((sym_lambda_a + sym_mu) ** 2 + sym_lambda_a * sym_lambda_o)
# Out:
#  4 ⎛                      2⎞
# μ ⋅⎝λ__A⋅λ__o + (λ__A + μ) ⎠

# %%
abg.markov.visualise_ambulance_markov_chain(num_of_servers=1, threshold=1, system_capacity=4, parking_capacity=1)

# %%
sym.fraction(sym.factor(probs_1141[p00]))[0]
# Out:
#  5 ⎛    3         2              2              2                           2
# μ ⋅⎝λ__A  + 2⋅λ__A ⋅λ__o + 3⋅λ__A ⋅μ + λ__A⋅λ__o  + 2⋅λ__A⋅λ__o⋅μ + 3⋅λ__A⋅μ
#
#    3⎞
# + μ ⎠

# %%
sym_mu ** 5 * ((sym_lambda_a + sym_mu) ** 3 + sym_lambda_a * sym_lambda_o * (2 * sym_lambda_a + sym_lambda_o + 2 * sym_mu))
# Out:
#  5 ⎛                                            3⎞
# μ ⋅⎝λ__A⋅λ__o⋅(2⋅λ__A + λ__o + 2⋅μ) + (λ__A + μ) ⎠

# %%
abg.markov.visualise_ambulance_markov_chain(num_of_servers=1, threshold=1, system_capacity=5, parking_capacity=1)

# %%
sym.fraction(sym.factor(probs_1151[p00]))[0]
# Out:
#  6 ⎛    4         3              3           2     2         2
# μ ⋅⎝λ__A  + 3⋅λ__A ⋅λ__o + 4⋅λ__A ⋅μ + 3⋅λ__A ⋅λ__o  + 6⋅λ__A ⋅λ__o⋅μ + 6⋅λ__A
#
# 2  2            3              2                  2           3    4⎞
#  ⋅μ  + λ__A⋅λ__o  + 2⋅λ__A⋅λ__o ⋅μ + 3⋅λ__A⋅λ__o⋅μ  + 4⋅λ__A⋅μ  + μ ⎠

# %%
sym_mu ** 6 * ((sym_lambda_a + sym_mu) ** 4 + sym_lambda_a * sym_lambda_o * ((3*sym_lambda_a + sym_lambda_o + 3*sym_mu) * (sym_lambda_a + sym_lambda_o + sym_mu) - sym_lambda_o * (sym_lambda_a + 2 * sym_mu)))
# Out:
#  6 ⎛
# μ ⋅⎝λ__A⋅λ__o⋅(-λ__o⋅(λ__A + 2⋅μ) + (λ__A + λ__o + μ)⋅(3⋅λ__A + λ__o + 3⋅μ)) +
#
#            4⎞
#  (λ__A + μ) ⎠

# %%
abg.markov.visualise_ambulance_markov_chain(num_of_servers=1, threshold=1, system_capacity=6, parking_capacity=1)

# %%
sym.fraction(sym.factor(probs_1161[p00]))[0]
# Out:
#  7 ⎛    5         4              4           3     2          3
# μ ⋅⎝λ__A  + 4⋅λ__A ⋅λ__o + 5⋅λ__A ⋅μ + 6⋅λ__A ⋅λ__o  + 12⋅λ__A ⋅λ__o⋅μ + 10⋅λ_
#
#   3  2         2     3         2     2            2       2          2  3
# _A ⋅μ  + 4⋅λ__A ⋅λ__o  + 9⋅λ__A ⋅λ__o ⋅μ + 12⋅λ__A ⋅λ__o⋅μ  + 10⋅λ__A ⋅μ  + λ_
#
#        4              3                2  2                3           4    5⎞
# _A⋅λ__o  + 2⋅λ__A⋅λ__o ⋅μ + 3⋅λ__A⋅λ__o ⋅μ  + 4⋅λ__A⋅λ__o⋅μ  + 5⋅λ__A⋅μ  + μ ⎠

# %%
sym_mu ** 7 * ((sym_lambda_a + sym_mu) ** 5 + sym_lambda_a * sym_lambda_o * ((4*sym_lambda_a + sym_lambda_o + 4*sym_mu) * (sym_lambda_a + sym_lambda_o + sym_mu) ** 2 - sym_lambda_o * (sym_lambda_a + 2 * sym_mu) * (3*sym_lambda_a + 2*sym_lambda_o + 3*sym_mu)))
# Out:
#  7 ⎛          ⎛                                                              2
# μ ⋅⎝λ__A⋅λ__o⋅⎝-λ__o⋅(λ__A + 2⋅μ)⋅(3⋅λ__A + 2⋅λ__o + 3⋅μ) + (λ__A + λ__o + μ)
#
#                       ⎞             5⎞
# ⋅(4⋅λ__A + λ__o + 4⋅μ)⎠ + (λ__A + μ) ⎠

# %% [markdown]
# # Summary

# %%
sym_mu ** 3 * (sym_lambda_a + sym_mu)
# Out:
#  3
# μ ⋅(λ__A + μ)

# %%
sym_mu ** 4 * ((sym_lambda_a + sym_mu) ** 2 + sym_lambda_a * sym_lambda_o)
# Out:
#  4 ⎛                      2⎞
# μ ⋅⎝λ__A⋅λ__o + (λ__A + μ) ⎠

# %%
sym_mu ** 5 * ((sym_lambda_a + sym_mu) ** 3 + sym_lambda_a * sym_lambda_o * (2 * sym_lambda_a + sym_lambda_o + 2 * sym_mu))
# Out:
#  5 ⎛                                            3⎞
# μ ⋅⎝λ__A⋅λ__o⋅(2⋅λ__A + λ__o + 2⋅μ) + (λ__A + μ) ⎠

# %%
sym_mu ** 6 * ((sym_lambda_a + sym_mu) ** 4 + sym_lambda_a * sym_lambda_o * ((3*sym_lambda_a + sym_lambda_o + 3*sym_mu) * (sym_lambda_a + sym_lambda_o + sym_mu) - sym_lambda_o * (sym_lambda_a + 2 * sym_mu)))
# Out:
#  6 ⎛
# μ ⋅⎝λ__A⋅λ__o⋅(-λ__o⋅(λ__A + 2⋅μ) + (λ__A + λ__o + μ)⋅(3⋅λ__A + λ__o + 3⋅μ)) +
#
#            4⎞
#  (λ__A + μ) ⎠

# %%
sym_mu ** 7 * ((sym_lambda_a + sym_mu) ** 5 + sym_lambda_a * sym_lambda_o * ((4*sym_lambda_a + sym_lambda_o + 4*sym_mu) * (sym_lambda_a + sym_lambda_o + sym_mu) ** 2 - sym_lambda_o * (sym_lambda_a + 2 * sym_mu) * (3*sym_lambda_a + 2*sym_lambda_o + 3*sym_mu)))
# Out:
#  7 ⎛          ⎛                                                              2
# μ ⋅⎝λ__A⋅λ__o⋅⎝-λ__o⋅(λ__A + 2⋅μ)⋅(3⋅λ__A + 2⋅λ__o + 3⋅μ) + (λ__A + λ__o + μ)
#
#                       ⎞             5⎞
# ⋅(4⋅λ__A + λ__o + 4⋅μ)⎠ + (λ__A + μ) ⎠

# %% [markdown]
# ## Does not match actual calculations

# %%
sym_mu ** 8 * ((sym_lambda_a + sym_mu) ** 6 + sym_lambda_a * sym_lambda_o * ((5*sym_lambda_a + sym_lambda_o + 5*sym_mu) * (sym_lambda_a + sym_lambda_o + sym_mu) ** 3 - sym_lambda_o * (sym_lambda_a + 2 * sym_mu) * (3*sym_lambda_a + 2*sym_lambda_o + 3*sym_mu) ** 2))
# Out:
#  8 ⎛          ⎛                                           2
# μ ⋅⎝λ__A⋅λ__o⋅⎝- λ__o⋅(λ__A + 2⋅μ)⋅(3⋅λ__A + 2⋅λ__o + 3⋅μ)  + (λ__A + λ__o + μ
#
#  3                      ⎞             6⎞
# ) ⋅(5⋅λ__A + λ__o + 5⋅μ)⎠ + (λ__A + μ) ⎠

# %%
print(sym.fraction(probs_1181[p00])[0])
# Out:
# mu**9*(lambda^A**7 + 6*lambda^A**6*lambda^o + 7*lambda^A**6*mu + 15*lambda^A**5*lambda^o**2 + 30*lambda^A**5*lambda^o*mu + 21*lambda^A**5*mu**2 + 20*lambda^A**4*lambda^o**3 + 50*lambda^A**4*lambda^o**2*mu + 60*lambda^A**4*lambda^o*mu**2 + 35*lambda^A**4*mu**3 + 15*lambda^A**3*lambda^o**4 + 40*lambda^A**3*lambda^o**3*mu + 60*lambda^A**3*lambda^o**2*mu**2 + 60*lambda^A**3*lambda^o*mu**3 + 35*lambda^A**3*mu**4 + 6*lambda^A**2*lambda^o**5 + 15*lambda^A**2*lambda^o**4*mu + 24*lambda^A**2*lambda^o**3*mu**2 + 30*lambda^A**2*lambda^o**2*mu**3 + 30*lambda^A**2*lambda^o*mu**4 + 21*lambda^A**2*mu**5 + lambda^A*lambda^o**6 + 2*lambda^A*lambda^o**5*mu + 3*lambda^A*lambda^o**4*mu**2 + 4*lambda^A*lambda^o**3*mu**3 + 5*lambda^A*lambda^o**2*mu**4 + 6*lambda^A*lambda^o*mu**5 + 7*lambda^A*mu**6 + mu**7)

# %% [markdown]
# # Saved outcomes

# %%
P00_1111 = sym_mu ** 2

P00_1121 = sym_mu ** 3 * (sym_lambda_a + sym_mu)

P00_1131 = sym_mu ** 4 * ((sym_lambda_a + sym_mu) ** 2 + sym_lambda_a * sym_lambda_o)

P00_1141 = sym_mu ** 5 * ((sym_lambda_a + sym_mu) ** 3 + sym_lambda_a * sym_lambda_o * (2 * sym_lambda_a + sym_lambda_o + 2 * sym_mu))

P00_1151 = sym_mu ** 6 * ((sym_lambda_a + sym_mu) ** 4 + sym_lambda_a * sym_lambda_o * ((3*sym_lambda_a + sym_lambda_o + 3*sym_mu) * (sym_lambda_a + sym_lambda_o + sym_mu) - sym_lambda_o * (sym_lambda_a + 2 * sym_mu)))

P00_1161 = sym_mu ** 7 * ((sym_lambda_a + sym_mu) ** 5 + sym_lambda_a * sym_lambda_o * ((4*sym_lambda_a + sym_lambda_o + 4*sym_mu) * (sym_lambda_a + sym_lambda_o + sym_mu) ** 2 - sym_lambda_o * (sym_lambda_a + 2 * sym_mu) * (3*sym_lambda_a + 2*sym_lambda_o + 3*sym_mu)))

P00_1171 = sym_mu**8*(sym_lambda_a**6 + 5*sym_lambda_a**5*sym_lambda_o + 6*sym_lambda_a**5*sym_mu + 10*sym_lambda_a**4*sym_lambda_o**2 + 20*sym_lambda_a**4*sym_lambda_o*sym_mu + 15*sym_lambda_a**4*sym_mu**2 + 10*sym_lambda_a**3*sym_lambda_o**3 + 24*sym_lambda_a**3*sym_lambda_o**2*sym_mu + 30*sym_lambda_a**3*sym_lambda_o*sym_mu**2 + 20*sym_lambda_a**3*sym_mu**3 + 5*sym_lambda_a**2*sym_lambda_o**4 + 12*sym_lambda_a**2*sym_lambda_o**3*sym_mu + 18*sym_lambda_a**2*sym_lambda_o**2*sym_mu**2 + 20*sym_lambda_a**2*sym_lambda_o*sym_mu**3 + 15*sym_lambda_a**2*sym_mu**4 + sym_lambda_a*sym_lambda_o**5 + 2*sym_lambda_a*sym_lambda_o**4*sym_mu + 3*sym_lambda_a*sym_lambda_o**3*sym_mu**2 + 4*sym_lambda_a*sym_lambda_o**2*sym_mu**3 + 5*sym_lambda_a*sym_lambda_o*sym_mu**4 + 6*sym_lambda_a*sym_mu**5 + sym_mu**6)

P00_1181 = sym_mu**9*(sym_lambda_a**7 + 6*sym_lambda_a**6*sym_lambda_o + 7*sym_lambda_a**6*sym_mu + 15*sym_lambda_a**5*sym_lambda_o**2 + 30*sym_lambda_a**5*sym_lambda_o*sym_mu + 21*sym_lambda_a**5*sym_mu**2 + 20*sym_lambda_a**4*sym_lambda_o**3 + 50*sym_lambda_a**4*sym_lambda_o**2*sym_mu + 60*sym_lambda_a**4*sym_lambda_o*sym_mu**2 + 35*sym_lambda_a**4*sym_mu**3 + 15*sym_lambda_a**3*sym_lambda_o**4 + 40*sym_lambda_a**3*sym_lambda_o**3*sym_mu + 60*sym_lambda_a**3*sym_lambda_o**2*sym_mu**2 + 60*sym_lambda_a**3*sym_lambda_o*sym_mu**3 + 35*sym_lambda_a**3*sym_mu**4 + 6*sym_lambda_a**2*sym_lambda_o**5 + 15*sym_lambda_a**2*sym_lambda_o**4*sym_mu + 24*sym_lambda_a**2*sym_lambda_o**3*sym_mu**2 + 30*sym_lambda_a**2*sym_lambda_o**2*sym_mu**3 + 30*sym_lambda_a**2*sym_lambda_o*sym_mu**4 + 21*sym_lambda_a**2*sym_mu**5 + sym_lambda_a*sym_lambda_o**6 + 2*sym_lambda_a*sym_lambda_o**5*sym_mu + 3*sym_lambda_a*sym_lambda_o**4*sym_mu**2 + 4*sym_lambda_a*sym_lambda_o**3*sym_mu**3 + 5*sym_lambda_a*sym_lambda_o**2*sym_mu**4 + 6*sym_lambda_a*sym_lambda_o*sym_mu**5 + 7*sym_lambda_a*sym_mu**6 + sym_mu**7)

# %%
P00_1111_simplified = P00_1111 / sym_mu ** 2
P00_1121_simplified = P00_1121 / sym_mu ** 3
P00_1131_simplified = P00_1131 / sym_mu ** 4
P00_1141_simplified = P00_1141 / sym_mu ** 5
P00_1151_simplified = P00_1151 / sym_mu ** 6
P00_1161_simplified = P00_1161 / sym_mu ** 7
P00_1171_simplified = P00_1171 / sym_mu ** 8
P00_1181_simplified = P00_1181 / sym_mu ** 9

# %%
P00_1111_simplified
# Out:
# 1

# %%
sym.expand(P00_1121_simplified)
# Out:
# λ__A + μ

# %%
sym.expand(P00_1131_simplified)
# Out:
#     2                           2
# λ__A  + λ__A⋅λ__o + 2⋅λ__A⋅μ + μ

# %%
sym.expand(P00_1141_simplified)
# Out:
#     3         2              2              2                           2    3
# λ__A  + 2⋅λ__A ⋅λ__o + 3⋅λ__A ⋅μ + λ__A⋅λ__o  + 2⋅λ__A⋅λ__o⋅μ + 3⋅λ__A⋅μ  + μ

# %%
sym.expand(P00_1151_simplified)
# Out:
#     4         3              3           2     2         2                2  2
# λ__A  + 3⋅λ__A ⋅λ__o + 4⋅λ__A ⋅μ + 3⋅λ__A ⋅λ__o  + 6⋅λ__A ⋅λ__o⋅μ + 6⋅λ__A ⋅μ
#
#             3              2                  2           3    4
#  + λ__A⋅λ__o  + 2⋅λ__A⋅λ__o ⋅μ + 3⋅λ__A⋅λ__o⋅μ  + 4⋅λ__A⋅μ  + μ

# %%
sym.expand(P00_1161_simplified)
# Out:
#     5         4              4           3     2          3                 3
# λ__A  + 4⋅λ__A ⋅λ__o + 5⋅λ__A ⋅μ + 6⋅λ__A ⋅λ__o  + 12⋅λ__A ⋅λ__o⋅μ + 10⋅λ__A ⋅
#
#  2         2     3         2     2            2       2          2  3
# μ  + 4⋅λ__A ⋅λ__o  + 9⋅λ__A ⋅λ__o ⋅μ + 12⋅λ__A ⋅λ__o⋅μ  + 10⋅λ__A ⋅μ  + λ__A⋅λ
#
#    4              3                2  2                3           4    5
# __o  + 2⋅λ__A⋅λ__o ⋅μ + 3⋅λ__A⋅λ__o ⋅μ  + 4⋅λ__A⋅λ__o⋅μ  + 5⋅λ__A⋅μ  + μ

# %%
sym.expand(P00_1171_simplified)
# Out:
#     6         5              5            4     2          4                 4
# λ__A  + 5⋅λ__A ⋅λ__o + 6⋅λ__A ⋅μ + 10⋅λ__A ⋅λ__o  + 20⋅λ__A ⋅λ__o⋅μ + 15⋅λ__A
#
#   2          3     3          3     2            3       2          3  3
# ⋅μ  + 10⋅λ__A ⋅λ__o  + 24⋅λ__A ⋅λ__o ⋅μ + 30⋅λ__A ⋅λ__o⋅μ  + 20⋅λ__A ⋅μ  + 5⋅λ
#
#    2     4          2     3            2     2  2          2       3
# __A ⋅λ__o  + 12⋅λ__A ⋅λ__o ⋅μ + 18⋅λ__A ⋅λ__o ⋅μ  + 20⋅λ__A ⋅λ__o⋅μ  + 15⋅λ__A
#
# 2  4            5              4                3  2              2  3
#  ⋅μ  + λ__A⋅λ__o  + 2⋅λ__A⋅λ__o ⋅μ + 3⋅λ__A⋅λ__o ⋅μ  + 4⋅λ__A⋅λ__o ⋅μ  + 5⋅λ__
#
#         4           5    6
# A⋅λ__o⋅μ  + 6⋅λ__A⋅μ  + μ

# %%
sym.expand(P00_1181_simplified)
# Out:
#     7         6              6            5     2          5                 5
# λ__A  + 6⋅λ__A ⋅λ__o + 7⋅λ__A ⋅μ + 15⋅λ__A ⋅λ__o  + 30⋅λ__A ⋅λ__o⋅μ + 21⋅λ__A
#
#   2          4     3          4     2            4       2          4  3
# ⋅μ  + 20⋅λ__A ⋅λ__o  + 50⋅λ__A ⋅λ__o ⋅μ + 60⋅λ__A ⋅λ__o⋅μ  + 35⋅λ__A ⋅μ  + 15⋅
#
#     3     4          3     3            3     2  2          3       3
# λ__A ⋅λ__o  + 40⋅λ__A ⋅λ__o ⋅μ + 60⋅λ__A ⋅λ__o ⋅μ  + 60⋅λ__A ⋅λ__o⋅μ  + 35⋅λ__
#
#  3  4         2     5          2     4            2     3  2          2     2
# A ⋅μ  + 6⋅λ__A ⋅λ__o  + 15⋅λ__A ⋅λ__o ⋅μ + 24⋅λ__A ⋅λ__o ⋅μ  + 30⋅λ__A ⋅λ__o ⋅
#
#  3          2       4          2  5            6              5
# μ  + 30⋅λ__A ⋅λ__o⋅μ  + 21⋅λ__A ⋅μ  + λ__A⋅λ__o  + 2⋅λ__A⋅λ__o ⋅μ + 3⋅λ__A⋅λ__
#
#  4  2              3  3              2  4                5           6    7
# o ⋅μ  + 4⋅λ__A⋅λ__o ⋅μ  + 5⋅λ__A⋅λ__o ⋅μ  + 6⋅λ__A⋅λ__o⋅μ  + 7⋅λ__A⋅μ  + μ
