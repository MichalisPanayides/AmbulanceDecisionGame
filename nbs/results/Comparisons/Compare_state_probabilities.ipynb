# %%
import ambulance_game as abg
import ciw
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Varying lambda_a

# %%
# Parameters
lambda_a_space = np.linspace(0.1, 0.5, 5)
lambda_o = 0.1
mu = 0.1
num_of_servers = 5
threshold = num_of_servers
system_capacity = 20
parking_capacity = 20
runtime = 10000

# %%
for lambda_a in lambda_a_space:
    abg.get_heatmaps(lambda_a, lambda_o, mu, num_of_servers, threshold, system_capacity, parking_capacity, runtime=runtime)

# %% [markdown]
# # Varying lambda_o

# %%
# Parameters
lambda_a = 0.1
lambda_o_space = np.linspace(0.2, 0.6, 5)
mu = 0.1
num_of_servers = 5
threshold = num_of_servers
system_capacity = 20
parking_capacity = 20

# %%
for lambda_o in lambda_o_space:
    abg.get_heatmaps(lambda_a, lambda_o, mu, num_of_servers, threshold, system_capacity, parking_capacity, runtime=runtime)

# %% [markdown]
# # Varying mu

# %%
# Parameters
lambda_a = 0.3
lambda_o = 0.3
mu_space = np.linspace(0.05, 0.55, 5)
num_of_servers = 5
threshold = num_of_servers
system_capacity = 20
parking_capacity = 20

# %%
for mu in mu_space:
    abg.get_heatmaps(lambda_a, lambda_o, mu, num_of_servers, threshold, system_capacity, parking_capacity, runtime=runtime)

# %% [markdown]
# # Varying num_of_servers

# %%
# Parameters
lambda_a = 0.2
lambda_o = 0.2
mu = 0.1
num_of_servers_space = np.linspace(1, 5, 5, dtype=int)
threshold = 5
system_capacity = 20
parking_capacity = 20

# %%
for num_of_servers_int in num_of_servers_space:
    num_of_servers = int(num_of_servers_int)
    abg.get_heatmaps(lambda_a, lambda_o, mu, num_of_servers, threshold, system_capacity, parking_capacity)

# %% [markdown]
# # Varying threshold

# %%
# Parameters
lambda_a = 0.2
lambda_o = 0.2
mu = 0.1
num_of_servers = 5
threshold_space = np.linspace(1, 9, 5, dtype=int)
system_capacity = 20
parking_capacity = 20

# %%
for threshold in threshold_space:
    abg.get_heatmaps(lambda_a, lambda_o, mu, num_of_servers, threshold, system_capacity, parking_capacity)
